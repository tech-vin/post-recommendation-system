# %% [markdown]
# # Recommendation System

# %% [markdown]
# In this recommendation system I have used Kaggle dataset named Post Recommendation System Here is the link of that : https://www.kaggle.com/vatsalparsaniya/post-pecommendation
#
# It will consume a user_id and check the history or like or vote he has given to post and check other users simliarities and then recommend posts.
#
# Here we go::::::::::::

# %%
#importing relevant libraries

import pandas as pd
import numpy as np
import re

# %%
#Datasets Importing 
#post_data consists of post details like post_id, title, category
#user_data consists of user's information
#view_data consists of which user view which post

post_data = pd.read_csv(r'posts.csv')
user_data = pd.read_csv(r'users.csv')
view_data = pd.read_csv(r'views.csv')

# %%
post_data.head()
# Out:
#                     post_id                          title  \
# 0  5d62abaa65218653a132c956                    hello there
# 1  5d6d39567fa40e1417a4931c                      Ml and AI
# 2  5d7d23315720533e15c3b1ee  What is an Operating System ?
# 3  5d7d405e5720533e15c3b1f3                     Lord Shiva
# 4  5d80dfbc6c53455f896e600e   How Competition law evolved?
#
#                                             category  post_type Unnamed: 4  \
# 0                                Plant Biotechnology       blog        NaN
# 1  Artificial Intelligence|Machine Learning|Infor...       blog        NaN
# 2                                  Operating Systems       blog        NaN
# 3                                           Drawings    artwork        NaN
# 4                                   Competition Laws       blog        NaN
#
#   Unnamed: 5
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
user_data.head()
# Out:
#                     post_id                  name gender      academics
# 0  5d60098a653a331687083238  Nivesh Singh Chauhan   male  undergraduate
# 1  5d610ae1653a331687083239         Gaurav Sharma   male       graduate
# 2  5d618359fc5fcf3bdd9a0910         Akshay Mishra   male  undergraduate
# 3  5d6d2bb87fa40e1417a49315        Saksham Mathur   male  undergraduate
# 4  5d7c994d5720533e15c3b1e9         Varun Chowhan   male  undergraduate

# %%
view_data.head()
# Out:
#                     user_id                   post_id  \
# 0  5df49b32cc709107827fb3c7  5ec821ddec493f4a2655889e
# 1  5ed3748576027d35905ccaab  5ed4cbadbd514d602c1531a6
# 2  5ed0defa76027d35905cc2de  5eac305f10426255a7aa9dd3
# 3  5ed0defa76027d35905cc2de  5ed1ff0276027d35905cc60d
# 4  5ed0defa76027d35905cc2de  5ed3820f76027d35905ccac8
#
#                   timestamp
# 0  2020-06-01T10:46:45.131Z
# 1  2020-06-01T09:39:20.021Z
# 2  2020-06-01T08:12:42.682Z
# 3  2020-06-01T08:10:23.880Z
# 4  2020-06-01T08:08:54.124Z

# %%
#Making Recommendation system is not a supervised learning right that consist of label but it is 
# unsupervised learning so we have to add likes or make it valuable that means the user rate it valuable
# in terms of rating like out of 5 okay
# I add up it.

dataframe = pd.DataFrame(view_data)

# %%
dataframe["Valuable"] = np.random.randint(1, 6, len(dataframe))

# %%
#this is our data right now.
dataframe
# Out:
#                        user_id                   post_id  \
# 0     5df49b32cc709107827fb3c7  5ec821ddec493f4a2655889e
# 1     5ed3748576027d35905ccaab  5ed4cbadbd514d602c1531a6
# 2     5ed0defa76027d35905cc2de  5eac305f10426255a7aa9dd3
# 3     5ed0defa76027d35905cc2de  5ed1ff0276027d35905cc60d
# 4     5ed0defa76027d35905cc2de  5ed3820f76027d35905ccac8
# ...                        ...                       ...
# 1444  5d60098a653a331687083238  5e7a60edcfc8b713f5ac7d82
# 1445  5d60098a653a331687083238  5e7a629ccfc8b713f5ac7d84
# 1446  5d60098a653a331687083238  5e7b1e65cfc8b713f5ac7d90
# 1447  5d60098a653a331687083238  5e7cc074cfc8b713f5ac7db0
# 1448  5d60098a653a331687083238  5e1029f22a37d20505da2a79
#
#                      timestamp  Valuable
# 0     2020-06-01T10:46:45.131Z         3
# 1     2020-06-01T09:39:20.021Z         5
# 2     2020-06-01T08:12:42.682Z         4
# 3     2020-06-01T08:10:23.880Z         3
# 4     2020-06-01T08:08:54.124Z         3
# ...                        ...       ...
# 1444  2020-03-26T19:03:55.284Z         1
# 1445  2020-03-26T19:01:42.384Z         2
# 1446  2020-03-26T19:00:25.693Z         4
# 1447  2020-03-26T18:49:14.721Z         5
# 1448  2020-03-26T18:25:45.637Z         2
#
# [1449 rows x 4 columns]

# %%
# in this cell we are merging view data and the dataframe I have made of post data. in this post id is common.

df = pd.merge(dataframe, post_data ,on='post_id')
df.tail()
# Out:
#                        user_id                   post_id  \
# 1442  5d60098a653a331687083238  5e294fd1c85ab714a7da6643
# 1443  5d610ae1653a331687083239  5e7c78fdcfc8b713f5ac7daa
# 1444  5d60098a653a331687083238  5dc065ca24b883670268772f
# 1445  5d60098a653a331687083238  5e7a5ebdcfc8b713f5ac7d7f
# 1446  5d60098a653a331687083238  5e7a629ccfc8b713f5ac7d84
#
#                      timestamp  Valuable                title  \
# 1442  2020-03-27T08:41:13.123Z         3      Personal growth
# 1443  2020-03-26T22:23:15.619Z         2         Types Of AI.
# 1444  2020-03-26T19:10:26.525Z         3  Colours of pushkar.
# 1445  2020-03-26T19:05:50.403Z         3       I won the Art.
# 1446  2020-03-26T19:01:42.384Z         2      3D composition.
#
#                                          category  post_type Unnamed: 4  \
# 1442           Mass Media|International Relations       blog        NaN
# 1443  Computer Technology|Artificial Intelligence       blog        NaN
# 1444                                  Photography    artwork        NaN
# 1445                                   Conceptual    artwork        NaN
# 1446                                     Tapestry    artwork        NaN
#
#      Unnamed: 5
# 1442        NaN
# 1443        NaN
# 1444        NaN
# 1445        NaN
# 1446        NaN

# %%
#drop the irrevelent features i.e category is important but not for this. and also time_stamp is not 
#important right now.
data = df.drop(['timestamp', 'category'], axis=1)

# %%
data.tail()
# Out:
#                        user_id                   post_id  Valuable  \
# 1442  5d60098a653a331687083238  5e294fd1c85ab714a7da6643         3
# 1443  5d610ae1653a331687083239  5e7c78fdcfc8b713f5ac7daa         2
# 1444  5d60098a653a331687083238  5dc065ca24b883670268772f         3
# 1445  5d60098a653a331687083238  5e7a5ebdcfc8b713f5ac7d7f         3
# 1446  5d60098a653a331687083238  5e7a629ccfc8b713f5ac7d84         2
#
#                     title  post_type Unnamed: 4 Unnamed: 5
# 1442      Personal growth       blog        NaN        NaN
# 1443         Types Of AI.       blog        NaN        NaN
# 1444  Colours of pushkar.    artwork        NaN        NaN
# 1445       I won the Art.    artwork        NaN        NaN
# 1446      3D composition.    artwork        NaN        NaN

# %%
# In this first we have to make a column here that consists of total ratings a title or a post have. 
#like 10 Funny ART Quotes has 15 votes given by users.

combine_post_rating = data.dropna(axis = 0, subset = ['title'])

post_ratingCount = (combine_post_rating.
     groupby(by = ['title'])['Valuable'].
     count().
     reset_index().
     rename(columns = {'Valuable': 'totalValuableCount'})
     [['title', 'totalValuableCount']]
    )
post_ratingCount.head()
# Out:
#                                                title  totalValuableCount
# 0                                   'The Virtual ME'                   3
# 1  10 Best Artificial Intelligence (AI) Courses O...                   2
# 2  10 Best UI UX Design Course & Certification [2...                   2
# 3          100 Free University Courses Online [2020]                   5
# 4  20 Best Data Science Certification & Courses f...                   1

# %%
#Merge it into our main dataset 
rating_with_totalValuableCount = combine_post_rating.merge(post_ratingCount, left_on = 'title', right_on = 'title', how = 'left')
rating_with_totalValuableCount.tail()
# Out:
#                        user_id                   post_id  Valuable  \
# 1442  5d60098a653a331687083238  5e294fd1c85ab714a7da6643         3
# 1443  5d610ae1653a331687083239  5e7c78fdcfc8b713f5ac7daa         2
# 1444  5d60098a653a331687083238  5dc065ca24b883670268772f         3
# 1445  5d60098a653a331687083238  5e7a5ebdcfc8b713f5ac7d7f         3
# 1446  5d60098a653a331687083238  5e7a629ccfc8b713f5ac7d84         2
#
#                     title  post_type Unnamed: 4 Unnamed: 5  totalValuableCount
# 1442      Personal growth       blog        NaN        NaN                   1
# 1443         Types Of AI.       blog        NaN        NaN                   1
# 1444  Colours of pushkar.    artwork        NaN        NaN                   1
# 1445       I won the Art.    artwork        NaN        NaN                   1
# 1446      3D composition.    artwork        NaN        NaN                   1

# %%
#It is just how to see data desciption and stuff.
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(post_ratingCount['totalValuableCount'].describe())
# Out:
# count   477.000
# mean      3.034
# std       2.786
# min       1.000
# 25%       1.000
# 50%       2.000
# 75%       4.000
# max      18.000
# Name: totalValuableCount, dtype: float64

# %%
print(post_ratingCount['totalValuableCount'].quantile(np.arange(.9, 1, .01)))
# Out:
# 0.900    7.000
# 0.910    7.000
# 0.920    7.920
# 0.930    8.000
# 0.940    8.440
# 0.950    9.000
# 0.960   10.000
# 0.970   11.000
# 0.980   12.000
# 0.990   13.240
# Name: totalValuableCount, dtype: float64

# %%
#we have to fix a threshold here that machine will recommend post to user that have votes greater than
# the threshold values
popularity_threshold = 13
rating_popular_post = rating_with_totalValuableCount.query('totalValuableCount >= @popularity_threshold')
rating_popular_post.tail()
# Out:
#                       user_id                   post_id  Valuable  \
# 673  5e3563348d344822fed4d13a  5ec2215374f7660d73aa1011         3
# 674  5defd51362624b0135ea9fd2  5ec2215374f7660d73aa1011         1
# 675  5e7cf05bcfc8b713f5ac7db7  5ec2215374f7660d73aa1011         2
# 676  5e35a5ed8d344822fed4d13e  5ec2215374f7660d73aa1011         4
# 677  5d60098a653a331687083238  5ec2215374f7660d73aa1011         5
#
#            title  post_type Unnamed: 4 Unnamed: 5  totalValuableCount
# 673  Women power    artwork        NaN        NaN                  13
# 674  Women power    artwork        NaN        NaN                  13
# 675  Women power    artwork        NaN        NaN                  13
# 676  Women power    artwork        NaN        NaN                  13
# 677  Women power    artwork        NaN        NaN                  13

# %%
rating_popular_post.shape
# Out:
# (102, 8)

# %%
user_data.head()
# Out:
#                     post_id                  name gender      academics
# 0  5d60098a653a331687083238  Nivesh Singh Chauhan   male  undergraduate
# 1  5d610ae1653a331687083239         Gaurav Sharma   male       graduate
# 2  5d618359fc5fcf3bdd9a0910         Akshay Mishra   male  undergraduate
# 3  5d6d2bb87fa40e1417a49315        Saksham Mathur   male  undergraduate
# 4  5d7c994d5720533e15c3b1e9         Varun Chowhan   male  undergraduate

# %%
len(user_data.gender.unique())
# Out:
# 3

# %% [markdown]
# Making model from here.
# we have to make a data matrix like indexes are titles and columns are user id and target is how valuable or how much likes it have.

# %% [markdown]
# Use here cosine similiarity to find the simliarity between user and other users.

# %%
from scipy.sparse import csr_matrix
rating_popular_post = rating_popular_post.drop_duplicates(['user_id', 'title'])
rating_popular_post_pivot = rating_popular_post.pivot(index = 'title', columns = 'user_id', values = 'Valuable').fillna(0)
rating_popular_post_matrix = csr_matrix(rating_popular_post_pivot.values)

from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(rating_popular_post_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
rating_popular_post_pivot.shape[0]
# Out:
# 7

# %%
rating_popular_post_pivot
# Out:
# user_id                                 5d60098a653a331687083238  \
# title
# Daaku                                                      1.000
# Faith in yourself                                          0.000
# Gangster Style                                             1.000
# Machine Learning”&“Operations" (MlOps)                     5.000
# The Waves Have Stood Still                                 3.000
# Understanding Cloud Computing(AWS)                         2.000
# Women power                                                5.000
#
# user_id                                 5d610ae1653a331687083239  \
# title
# Daaku                                                      2.000
# Faith in yourself                                          2.000
# Gangster Style                                             1.000
# Machine Learning”&“Operations" (MlOps)                     5.000
# The Waves Have Stood Still                                 5.000
# Understanding Cloud Computing(AWS)                         0.000
# Women power                                                0.000
#
# user_id                                 5d618359fc5fcf3bdd9a0910  \
# title
# Daaku                                                      1.000
# Faith in yourself                                          2.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     0.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         5.000
# Women power                                                0.000
#
# user_id                                 5d6d2bb87fa40e1417a49315  \
# title
# Daaku                                                      1.000
# Faith in yourself                                          3.000
# Gangster Style                                             4.000
# Machine Learning”&“Operations" (MlOps)                     4.000
# The Waves Have Stood Still                                 5.000
# Understanding Cloud Computing(AWS)                         0.000
# Women power                                                4.000
#
# user_id                                 5d7c994d5720533e15c3b1e9  \
# title
# Daaku                                                      5.000
# Faith in yourself                                          4.000
# Gangster Style                                             5.000
# Machine Learning”&“Operations" (MlOps)                     3.000
# The Waves Have Stood Still                                 5.000
# Understanding Cloud Computing(AWS)                         0.000
# Women power                                                3.000
#
# user_id                                 5de50d768eab6401affbb135  \
# title
# Daaku                                                      1.000
# Faith in yourself                                          5.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     5.000
# The Waves Have Stood Still                                 1.000
# Understanding Cloud Computing(AWS)                         0.000
# Women power                                                0.000
#
# user_id                                 5deeef6142a8854bf6eabab9  \
# title
# Daaku                                                      5.000
# Faith in yourself                                          5.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     2.000
# The Waves Have Stood Still                                 3.000
# Understanding Cloud Computing(AWS)                         5.000
# Women power                                                1.000
#
# user_id                                 5defd51362624b0135ea9fd2  \
# title
# Daaku                                                      4.000
# Faith in yourself                                          3.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     3.000
# The Waves Have Stood Still                                 1.000
# Understanding Cloud Computing(AWS)                         0.000
# Women power                                                1.000
#
# user_id                                 5df20f1fee4bb5252b4f5351  \
# title
# Daaku                                                      5.000
# Faith in yourself                                          1.000
# Gangster Style                                             5.000
# Machine Learning”&“Operations" (MlOps)                     0.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         0.000
# Women power                                                0.000
#
# user_id                                 5df49b32cc709107827fb3c7  ...  \
# title                                                             ...
# Daaku                                                      4.000  ...
# Faith in yourself                                          0.000  ...
# Gangster Style                                             3.000  ...
# Machine Learning”&“Operations" (MlOps)                     5.000  ...
# The Waves Have Stood Still                                 0.000  ...
# Understanding Cloud Computing(AWS)                         0.000  ...
# Women power                                                1.000  ...
#
# user_id                                 5ecdf7397023451e66223784  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     3.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         2.000
# Women power                                                0.000
#
# user_id                                 5ece02427023451e66223861  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     0.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         5.000
# Women power                                                0.000
#
# user_id                                 5ecfbcb376027d35905cbfe5  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     5.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         0.000
# Women power                                                0.000
#
# user_id                                 5ed0bfc176027d35905cc1f8  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     1.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         5.000
# Women power                                                0.000
#
# user_id                                 5ed0d9bc76027d35905cc2c2  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     0.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         3.000
# Women power                                                0.000
#
# user_id                                 5ed0dfec76027d35905cc2ec  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     0.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         1.000
# Women power                                                0.000
#
# user_id                                 5ed0fc0976027d35905cc448  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     0.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         3.000
# Women power                                                0.000
#
# user_id                                 5ed12ae476027d35905cc4a1  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     0.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         1.000
# Women power                                                0.000
#
# user_id                                 5ed232b976027d35905cc689  \
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     5.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         3.000
# Women power                                                0.000
#
# user_id                                 5ed24d5a76027d35905cc7d7
# title
# Daaku                                                      0.000
# Faith in yourself                                          0.000
# Gangster Style                                             0.000
# Machine Learning”&“Operations" (MlOps)                     0.000
# The Waves Have Stood Still                                 0.000
# Understanding Cloud Computing(AWS)                         5.000
# Women power                                                0.000
#
# [7 rows x 33 columns]

# %% [markdown]
# Choose a random users and recommend it a title of post by looking their cosine simliarity scores

# %%
query_index = np.random.choice(rating_popular_post_pivot.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(rating_popular_post_pivot.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# 1

# %%
# this is our name of user 3 and title he has seen or vote it and our task is to recommend it similiar
#post
rating_popular_post_pivot.index[query_index]
# Out:
# 'Faith in yourself'

# %%
#Here we go
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(rating_popular_post_pivot.index[query_index]))
    else:
        print('{0}: {1}, with distance of {2}:'.format(i, rating_popular_post_pivot.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for Faith in yourself:
#
# 1: The Waves Have Stood Still, with distance of 0.26940521207549284:
# 2: Daaku, with distance of 0.2892181863449912:
# 3: Women power, with distance of 0.4472100071772179:
# 4: Machine Learning”&“Operations" (MlOps), with distance of 0.501422477989084:
# 5: Gangster Style, with distance of 0.7060264390366804:
